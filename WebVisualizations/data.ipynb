# %%
import pandas as pd

# %%
 weather_cities = "Resources/cities.csv"

# %%
cities_data = pd.read_csv(weather_cities)

# %%
cities_data.head()
# Out:
#    Unnamed: 0       City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           0      vaini -21.20 -175.20     75.20        69          75
# 1           1   zhigansk  66.77  123.37     47.43        75         100
# 2           2  hithadhoo  -0.60   73.08     82.15        76         100
# 3           3   cabedelo  -6.98  -34.83     71.60        88          23
# 4           4  jamestown  42.10  -79.24     68.00        67           1
#
#    Wind Speed Country        Date
# 0       13.87      TO  1599438878
# 1       19.04      RU  1599439413
# 2       11.23      MV  1599439413
# 3        3.36      BR  1599439413
# 4        4.70      US  1599439414

# %%
data_html = cities_data.to_html()
print(data_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>vaini</td>
#       <td>-21.20</td>
#       <td>-175.20</td>
#       <td>75.20</td>
#       <td>69</td>
#       <td>75</td>
#       <td>13.87</td>
#       <td>TO</td>
#       <td>1599438878</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>zhigansk</td>
#       <td>66.77</td>
#       <td>123.37</td>
#       <td>47.43</td>
#       <td>75</td>
#       <td>100</td>
#       <td>19.04</td>
#       <td>RU</td>
#       <td>1599439413</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
